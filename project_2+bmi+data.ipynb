# %%
import pandas as pd

# %%
md=pd.read_csv(r"C:\Users\student714\Desktop\AHTESHAM ZAIDI\500-person-gender-height-weight-bodymassindex\500_person_gender_height_weight_index.csv")

# %%
md.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
ix=pd.Series(["Extremely Weak","Weak","Normal"," Overweight","Obesity","Extreme Obesity"])

# %%
ix
# Out:
# 0     Extremely Weak
# 1               Weak
# 2             Normal
# 3         Overweight
# 4            Obesity
# 5    Extreme Obesity
# dtype: object

# %%
m = md[md["Gender"]=="Male"]

# %%
m
# Out:
#     Gender  Height  Weight  Index
# 0     Male     174      96      4
# 1     Male     189      87      2
# 4     Male     149      61      3
# 5     Male     189     104      3
# 6     Male     147      92      5
# 7     Male     154     111      5
# 8     Male     174      90      3
# 10    Male     195      81      2
# 13    Male     155      51      2
# 14    Male     191      79      2
# 17    Male     140     129      5
# 18    Male     144     145      5
# 19    Male     172     139      5
# 20    Male     157     110      5
# 23    Male     185     139      5
# 26    Male     190      95      3
# 27    Male     187      62      1
# 29    Male     179     152      5
# 30    Male     153     121      5
# 31    Male     178      52      1
# 37    Male     144      80      4
# 42    Male     157      56      2
# 43    Male     161     118      5
# 45    Male     185      76      2
# 47    Male     181     111      4
# 48    Male     161      72      3
# ...

# %%
f=md[md["Gender"]=="Female"]

# %%
f
# Out:
#      Gender  Height  Weight  Index
# 2    Female     185     110      4
# 3    Female     195     104      3
# 9    Female     169     103      4
# 11   Female     159      80      4
# 12   Female     192     101      3
# 15   Female     153     107      5
# 16   Female     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 24   Female     172      67      2
# 25   Female     151      64      3
# 28   Female     163     159      5
# 32   Female     195      65      1
# 33   Female     160     131      5
# 34   Female     157     153      5
# 35   Female     189     132      4
# 36   Female     197     114      3
# 38   Female     171     152      5
# 39   Female     185      81      2
# 40   Female     175     120      4
# 41   Female     149     108      5
# 44   Female     182     126      4
# 46   Female     188     122      4
# 50   Female     168     135      5
# 51   Female     176      54      1
# 55   Female     187      89      3
# ...

# %%
len(f)
# Out:
# 255

# %%
len(m)
# Out:
# 245

# %%
#male in each cat
m0=len(m[m["Index"]==0])
m1=len(m[m["Index"]==1])
m2=len(m[m["Index"]==2])
m3=len(m[m["Index"]==3])
m4=len(m[m["Index"]==4])
m5=len(m[m["Index"]==5])

# %%
#female in each cat
f0=len(f[f["Index"]==0])
f1=len(f[f["Index"]==1])
f2=len(f[f["Index"]==2])
f3=len(f[f["Index"]==3])
f4=len(f[f["Index"]==4])
f5=len(f[f["Index"]==5])

# %%
f0
# Out:
# 7

# %%
m0
# Out:
# 6

# %%
mc=pd.Series([m0,m1,m2,m3,m4,m5])
fc=pd.Series([f0,f1,f2,f3,f4,f5])

# %%
mfc=pd.DataFrame({"Male":mc,"Female":fc})

# %%
mfc
# Out:
#    Female  Male
# 0       7     6
# 1       7    15
# 2      41    28
# 3      36    32
# 4      71    59
# 5      93   105

# %%
pm0=245/m0
pm1=245/m1
pm2=245/m2
pm3=245/m3
pm4=245/m4
pm5=245/m5
pf0=255/f0
pf1=255/f1
pf2=255/f2
pf3=255/f3
pf4=255/f4
pf5=255/f5
pmlist=pd.Series([pm0,pm1,pm2,pm3,pm4,pm5])
pflist=pd.Series([pf0,pf1,pf2,pf3,pf4,pf5])

# %%
mfc["%Male"]=pmlist

# %%
mfc["%Female"]=pflist

# %%
mfc
# Out:
#    Female  Male      %Male    %Female
# 0       7     6  40.833333  36.428571
# 1       7    15  16.333333  36.428571
# 2      41    28   8.750000   6.219512
# 3      36    32   7.656250   7.083333
# 4      71    59   4.152542   3.591549
# 5      93   105   2.333333   2.741935

# %%
#Female ... calssification...model
f.head()
# Out:
#     Gender  Height  Weight  Index
# 2   Female     185     110      4
# 3   Female     195     104      3
# 9   Female     169     103      4
# 11  Female     159      80      4
# 12  Female     192     101      3

# %%
fhwi=f.drop("Gender",axis=1)
mhwi=m.drop("Gender",axis=1)

# %%
mhwi
# Out:
#      Height  Weight  Index
# 0       174      96      4
# 1       189      87      2
# 4       149      61      3
# 5       189     104      3
# 6       147      92      5
# 7       154     111      5
# 8       174      90      3
# 10      195      81      2
# 13      155      51      2
# 14      191      79      2
# 17      140     129      5
# 18      144     145      5
# 19      172     139      5
# 20      157     110      5
# 23      185     139      5
# 26      190      95      3
# 27      187      62      1
# 29      179     152      5
# 30      153     121      5
# 31      178      52      1
# 37      144      80      4
# 42      157      56      2
# 43      161     118      5
# 45      185      76      2
# 47      181     111      4
# 48      161      72      3
# 49      140     152      5
# 52      163     110      5
# 53      172     105      4
# 54      196     116      4
# ..      ...     ...    ...
# 438     188      65      1
# 441     182      73      2
# ...

# %%
#female input and target
fhw=fhwi.drop("Index",axis=1)
fi=fhwi["Index"]
#male input and taregt
mhw=mhwi.drop("Index",axis=1)
mi=mhwi["Index"]

# %%
#female data fhw(feature) and fi(target)
from sklearn.model_selection import train_test_split

# %%
fxtrain,fxtest,fytrain,fytest=train_test_split(fhw,fi,test_size=.20,random_state=10)
mxtrain,mxtest,mytrain,mytest=train_test_split(mhw,mi,test_size=.20,random_state=10)

# %% [raw]
# #learner trainer data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#female classification
ft=KNeighborsClassifier()

# %%
fm=ft.fit(fxtrain,fytrain)

# %%
#male classification
mt=KNeighborsClassifier()
ml=mt.fit(mxtrain,mytrain)

# %%
#prediction
pm=ml.predict([[145,160]])
ix[pm]
# Out:
# 5    Extreme Obesity
# dtype: object

# %%
pm
# Out:
# array([5], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
yfa=fytest
yma=mytest

# %%
ypm=ml.predict(mxtest)

# %%
ypf=fm.predict(fxtest)

# %%
macc=float(accuracy_score(yma,ypm))*100

# %%
facc=float(accuracy_score(yfa,ypf))*100

# %%
print("male accuracy is{} female accuracy {}".format(macc,facc))
# Out:
# male accuracy is89.79591836734694 female accuracy 92.15686274509804
